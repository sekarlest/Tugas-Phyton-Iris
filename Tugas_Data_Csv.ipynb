# %%
import pandas as pd

# %%
df = pd.read_csv('https://query.data.world/s/f2yvvjxauuscnxmasmho4n4sptwlui')

# %%
df.head ()
# Out:
#       DBN Grade  Year   Demographic  Number Tested Mean Scale Score  \
# 0  01M015     3  2006  All Students             39              667
# 1  01M015     3  2007  All Students             31              672
# 2  01M015     3  2008  All Students             37              668
# 3  01M015     3  2009  All Students             33              668
# 4  01M015     3  2010  All Students             26              677
#
#   Num Level 1 Pct Level 1 Num Level 2 Pct Level 2 Num Level 3 Pct Level 3  \
# 0           2         5.1          11        28.2          20        51.3
# 1           2         6.5           3         9.7          22          71
# 2           0           0           6        16.2          29        78.4
# 3           0           0           4        12.1          28        84.8
# 4           6        23.1          12        46.2           6        23.1
#
#   Num Level 4 Pct Level 4 Num Level 3 and 4 Pct Level 3 and 4
# ...

# %%
df.tail ()
# Out:
#           DBN       Grade  Year   Demographic  Number Tested Mean Scale Score  \
# 33456  75X723  All Grades  2008  All Students            211              NaN
# 33457  75X723  All Grades  2009  All Students            209              NaN
# 33458  75X723  All Grades  2010  All Students            242              NaN
# 33459  75X723  All Grades  2011  All Students            229              617
# 33460  75X723  All Grades  2012  All Students            213              620
#
#       Num Level 1 Pct Level 1 Num Level 2 Pct Level 2 Num Level 3 Pct Level 3  \
# 33456         139        65.9          46        21.8          26        12.3
# 33457          88        42.1          87        41.6          30        14.4
# 33458         157        64.9          75          31          10         4.1
# 33459         153        66.8          67        29.3           8         3.5
# 33460         142        66.7          67        31.5           4         1.9
#
# ...

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33461 entries, 0 to 33460
# Data columns (total 16 columns):
# DBN                  33461 non-null object
# Grade                33461 non-null object
# Year                 33461 non-null int64
# Demographic          33461 non-null object
# Number Tested        33461 non-null int64
# Mean Scale Score     28106 non-null object
# Num Level 1          33461 non-null object
# Pct Level 1          33461 non-null object
# Num Level 2          33461 non-null object
# Pct Level 2          33461 non-null object
# Num Level 3          33461 non-null object
# Pct Level 3          33461 non-null object
# Num Level 4          33461 non-null object
# Pct Level 4          33461 non-null object
# Num Level 3 and 4    33461 non-null object
# Pct Level 3 and 4    33461 non-null object
# dtypes: int64(2), object(14)
# memory usage: 4.1+ MB

# %%
df.describe ()
# Out:
#                Year  Number Tested
# count  33461.000000   33461.000000
# mean    2009.066137     172.754132
# std        1.991814     197.130818
# min     2006.000000       1.000000
# 25%     2007.000000      65.000000
# 50%     2009.000000     106.000000
# 75%     2011.000000     204.000000
# max     2012.000000    2282.000000

# %%
df.groupby('Num Level 1').mean()
# Out:
#                     Year  Number Tested
# Num Level 1
# 0            2009.098901      90.608370
# 1            2009.097332     100.287671
# 10           2009.176471     149.746524
# 100          2008.642857     658.071429
# 101          2007.769231     486.307692
# ...                  ...            ...
# 96           2007.583333     470.833333
# 97           2009.222222     594.333333
# 98           2009.187500     557.937500
# 99           2008.722222     646.111111
# s            2008.951318       2.531440
#
# [269 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
x = (26, 31, 33, 37, 39)
print (x)
# Out:
# (26, 31, 33, 37, 39)

# %%
y = (677, 672, 668, 668, 667)
print (y)
# Out:
# (677, 672, 668, 668, 667)

# %%
plt.plot(x,y, '-', color='red')
plt.title('Graphic of Number Tested vs Mean Scale Score for Math Test')
plt.ylabel('Mean Scale Score')
plt.xlabel('Number Tested')
# Out:
# Text(0.5, 0, 'Number Tested')
